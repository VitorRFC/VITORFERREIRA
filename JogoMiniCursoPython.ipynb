# %% [markdown]
# <a href="https://colab.research.google.com/github/VitorRFC/VITORFERREIRA/blob/master/JogoMiniCursoPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def imprimeMenu():
  print("1-Inicia o jogo")
  print("2-Creditos do jogo")
  print("3-Sair\n")

def iniciaJogo(inicia):
  print("\nBem-Vindo ao jogo")
  s=10
  d=10
  vs=10
  f=10
  sim=1
  nao=2
  
  pergunta1= ["\nVoce gostaria de trabalhar via HomeOffice? ","\nVoce gostaria de aprender nova linguagem? ","\nGostaria de fazer Hora Extra essa semana? "]
  pergunta2= ["\nIniciamos uma StartUp gostaria de fazer parte da equipe","\nVoce conseguiu concluir aquele codigo? ","\nGostaria de representar a empresa no evento? "]
  perguntas= pergunta1 + pergunta2
  for contador in perguntas: 
    print(contador)
    escolha=input("1- Sim ou 2- Nao: ")
    escolha=int(escolha)
    
    if contador==perguntas[0]: #home office
      if escolha==sim:
        print("SUA SAUDE E DINHEIRO AUMENTARAM\n")
        s=s+5
        d=d+3
        print("Saude",s,"\nDinheiro",d,"\nVida social",vs,"\nFama",f)
      else:
        print("SUA VIDA SOCIAL E FAMA FICARAM ABALADAS\n")
        vs= vs-3
        f = f-2
        print("Saude",s,"\nDinheiro",d,"\nVida social",vs,"\nFama",f)
       
          
    if contador==perguntas[1]: #nova linguagem
      if escolha==sim:
        print("SUA GRANA E FAMA AUMETARAM\n")
        d=d+3
        f=f+5
        print("Saude",s,"\nDinheiro",d,"\nVida social",vs,"\nFama",f)
      else:
        print("SUA SAUDE E VIDA SOCIAL FICARAM ABALADAS\n")
        s= s-2
        vs = vs-2
        print("Saude",s,"\nDinheiro",d,"\nVida social",vs,"\nFama",f)
           
    
    if contador==perguntas[2]: #hora extra
      if escolha==sim:
        print("SUA GRANA E FAMA AUMETARAM\n")
        d=d+4
        f=f+3
        print("Saude",s,"\nDinheiro",d,"\nVida social",vs,"\nFama",f)
      else:
        print("SUA SAUDE E VIDA SOCIAL FICARAM ABALADAS\n")
        s= s-4
        vs= vs-5
        print("Saude",s,"\nDinheiro",d,"\nVida social",vs,"\nFama",f)
        
    
    if contador==perguntas[3]: #startup
      if escolha==sim:
        print("SUA SAUDE E VIDA SOCIAL AUMENTARAM\n")
        s=s+2
        vs=vs+4
        print("Saude",s,"\nDinheiro",d,"\nVida social",vs,"\nFama",f)
      else:
        print("SUA GRANA E FAMA FICARAM ABALADAS\n")
        d= d-2
        f = f-2
        print("Saude",s,"\nDinheiro",d,"\nVida social",vs,"\nFama",f)
          
    
    if contador==perguntas[4]: #atraso na entrega
      if escolha==sim:
        print("SUA SAUDE E VIDA SOCIAL AUMENTARAM\n")
        s=s+3
        vs=vs+2
        print("Saude",s,"\nDinheiro",d,"\nVida social",vs,"\nFama",f)
      else:
        print("SUA GRANA E FAMA FICARAM ABALADAS\n")
        d= d-4
        f = f-6
        print("Saude",s,"\nDinheiro",d,"\nVida social",vs,"\nFama",f)
        
     
    if contador==perguntas[5]: #participacao de evento
      if escolha==sim:
        print("SUA VIDA SOCIAL E FAMA AUMENTARAM\n")
        vs=vs+4
        f=f+2
        print("Saude",s,"\nDinheiro",d,"\nVida social",vs,"\nFama",f)
      else:
        print("SUA SAUDE E GRANA FICARAM ABALADAS\n")
        s= s-4
        d = d-4
        print("Saude",s,"\nDinheiro",d,"\nVida social",vs,"\nFama",f)
            

  if s==0 or d==0 or vs==0 or f==0:
    print("\nVoce perdeu!","\nVIDA",s,"\nDINHEIRO",d,"\nVIDA SOCIAL",vs,"\nFAMA",f)
  else:
    print("\nParabéns, Voce ganhou!","\nVIDA",s,"\nDINHEIRO",d,"\nVIDA SOCIAL",vs,"\nFAMA",f,"\n")   
  
  print("\nObrigado por jogar\n\n")
  funcaoprincipal()
  

    
def mostraCreditos(mostrar):
  print("Este jogo foi feito por: Vitor Ferreira\nEstudande de computação do IF\n")

def finaliza(fim):
  print("obrigado!")
  exit

def funcaoprincipal():
  imprimeMenu()

  while True:
    i=input("Escolha uma opcao: ")
    i=int(i)
    
    if i == 1:
      iniciaJogo(i)
    elif i == 2:
      mostraCreditos(i)
      break
    elif i == 3:
      finaliza(i) 
      break 
    else:
      print("inválido, digite outro valor\n")

funcaoprincipal()
